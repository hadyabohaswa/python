# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('MathZohr.csv')
df
# Out:
#                  username                                 firstname lastname  \
# 0     zohrst30@sta.edu.eg  Ibrahim Bassam Abdelgawad Ibrahim Meqled        .
# 1     zohrst31@sta.edu.eg        Ibrahim Atef Ali Sayed Ahmed Helal        .
# 2     zohrst12@sta.edu.eg   Ahmed Tamer Mosaad Abdelmenaem El Gohry        .
# 3      zohrst1@sta.edu.eg   Ahmed Hassan Farouk Abdelmoty Mohameden        .
# 4     zohrst13@sta.edu.eg          Ahmed Samy Elsayed Ali Elgedeedy        .
# ..                    ...                                       ...      ...
# 236  zohrst232@sta.edu.eg      Mahmoud Mohamed Hafez Hassan Elsayad        .
# 237  zohrst233@sta.edu.eg   Mostafa Mohamed Mohamed Youseef El Azab        .
# 238  zohrst234@sta.edu.eg      Mostafa Mohamed Mostafa Thabet Maaty        .
# 239  zohrst145@sta.edu.eg     Menna Allah Medhat Eid Elsaeed Borham        .
# 240  zohrst236@sta.edu.eg    Yousef Raafat Kamel Abdelmeghed Assran        .
#
#                     email  course1  group1
# ...

# %%
df.head()
# Out:
#               username                                 firstname lastname  \
# 0  zohrst30@sta.edu.eg  Ibrahim Bassam Abdelgawad Ibrahim Meqled        .
# 1  zohrst31@sta.edu.eg        Ibrahim Atef Ali Sayed Ahmed Helal        .
# 2  zohrst12@sta.edu.eg   Ahmed Tamer Mosaad Abdelmenaem El Gohry        .
# 3   zohrst1@sta.edu.eg   Ahmed Hassan Farouk Abdelmoty Mohameden        .
# 4  zohrst13@sta.edu.eg          Ahmed Samy Elsayed Ali Elgedeedy        .
#
#                  email  course1 group1
# 0  zohrst30@sta.edu.eg  رياضيات  (3/1)
# 1  zohrst31@sta.edu.eg  رياضيات  (3/1)
# 2  zohrst12@sta.edu.eg  رياضيات  (3/1)
# 3   zohrst1@sta.edu.eg  رياضيات  (3/1)
# 4  zohrst13@sta.edu.eg  رياضيات  (3/1)

# %%
df.tail()
# Out:
#                  username                                firstname lastname  \
# 236  zohrst232@sta.edu.eg     Mahmoud Mohamed Hafez Hassan Elsayad        .
# 237  zohrst233@sta.edu.eg  Mostafa Mohamed Mohamed Youseef El Azab        .
# 238  zohrst234@sta.edu.eg     Mostafa Mohamed Mostafa Thabet Maaty        .
# 239  zohrst145@sta.edu.eg    Menna Allah Medhat Eid Elsaeed Borham        .
# 240  zohrst236@sta.edu.eg   Yousef Raafat Kamel Abdelmeghed Assran        .
#
#                     email  course1  group1
# 236  zohrst232@sta.edu.eg  رياضيات  (3/10)
# 237  zohrst233@sta.edu.eg  رياضيات  (3/10)
# 238  zohrst234@sta.edu.eg  رياضيات  (3/10)
# 239  zohrst145@sta.edu.eg  رياضيات  (3/10)
# 240  zohrst236@sta.edu.eg  رياضيات  (3/10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   username   241 non-null    object
#  1   firstname  241 non-null    object
#  2   lastname   241 non-null    object
#  3   email      241 non-null    object
#  4   course1    241 non-null    object
#  5   group1     241 non-null    object
# dtypes: object(6)
# memory usage: 11.4+ KB

# %%
df.describe()
# Out:
#                    username                                 firstname  \
# count                   241                                       241
# unique                  241                                       241
# top     zohrst30@sta.edu.eg  Ibrahim Bassam Abdelgawad Ibrahim Meqled
# freq                      1                                         1
#
#        lastname                email  course1 group1
# count       241                  241      241    241
# unique        1                  241        1     10
# top           .  zohrst30@sta.edu.eg  رياضيات  (3/7)
# freq        241                    1      241     26

# %%
df
# Out:
#                  username                                 firstname lastname  \
# 0     zohrst30@sta.edu.eg  Ibrahim Bassam Abdelgawad Ibrahim Meqled        .
# 1     zohrst31@sta.edu.eg        Ibrahim Atef Ali Sayed Ahmed Helal        .
# 2     zohrst12@sta.edu.eg   Ahmed Tamer Mosaad Abdelmenaem El Gohry        .
# 3      zohrst1@sta.edu.eg   Ahmed Hassan Farouk Abdelmoty Mohameden        .
# 4     zohrst13@sta.edu.eg          Ahmed Samy Elsayed Ali Elgedeedy        .
# ..                    ...                                       ...      ...
# 236  zohrst232@sta.edu.eg      Mahmoud Mohamed Hafez Hassan Elsayad        .
# 237  zohrst233@sta.edu.eg   Mostafa Mohamed Mohamed Youseef El Azab        .
# 238  zohrst234@sta.edu.eg      Mostafa Mohamed Mostafa Thabet Maaty        .
# 239  zohrst145@sta.edu.eg     Menna Allah Medhat Eid Elsaeed Borham        .
# 240  zohrst236@sta.edu.eg    Yousef Raafat Kamel Abdelmeghed Assran        .
#
#                     email  course1  group1
# ...

# %%
df[['username' , 'group1']]
# Out:
#                  username  group1
# 0     zohrst30@sta.edu.eg   (3/1)
# 1     zohrst31@sta.edu.eg   (3/1)
# 2     zohrst12@sta.edu.eg   (3/1)
# 3      zohrst1@sta.edu.eg   (3/1)
# 4     zohrst13@sta.edu.eg   (3/1)
# ..                    ...     ...
# 236  zohrst232@sta.edu.eg  (3/10)
# 237  zohrst233@sta.edu.eg  (3/10)
# 238  zohrst234@sta.edu.eg  (3/10)
# 239  zohrst145@sta.edu.eg  (3/10)
# 240  zohrst236@sta.edu.eg  (3/10)
#
# [241 rows x 2 columns]

# %%
categories = df['group1'].value_counts()
categories
# Out:
# group1
# (3/7)     26
# (3/5)     25
# (3/6)     25
# (3/8)     25
# (3/1)     24
# (3/2)     24
# (3/3)     24
# (3/4)     23
# (3/9)     23
# (3/10)    22
# Name: count, dtype: int64

# %%
plt.plot(categories, 'bo-')
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(categories.index, categories.values)
plt.xticks(rotation=90)
plt.show()

# %%
plt.pie(categories, startangle=90, labels=categories.values)
plt.legend(labels=categories.index, loc=('upper right'))
